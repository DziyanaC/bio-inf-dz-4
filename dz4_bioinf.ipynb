# %%
# !chmod a+x zhunt3-alan.c

# %%
# !echo "CACACACACACA" > tmp.txt

# %%
# !gcc zhunt3-alan.c -lm -o zhunt3

# %%
# !./zhunt3
# Out:
# usage: zhunt windowsize minsize maxsize datafile

# %%
# !./zhunt3 12 8 12 tmp.txt

# %%
# !gunzip -d eboVir3.fa.gz

# %%
# !./zhunt3 12 8 12 eboVir3.fa chr19

# %%
# !cat eboVir3.fa.Z-SCORE
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# 13958 13974 16  27.731  32.391 4.169185e+00 ttgtacattcaggttt   SASASASASASASASA
# 13959 13975 16  27.766  28.961 4.100917e+00 tgtacattcaggtttt   ASASASASASASASAS
# 13960 13976 16  27.811  32.114 4.014699e+00 gtacattcaggtttta   SASASASASASAASAS
# 13961 13977 16  30.932  21.050 3.191897e-01 tacattcaggttttat   ASASASASSASASASA
# 13962 13978 16  29.944  30.720 4.574371e-01 acattcaggttttatc   SASASASASAASASAS
# 13963 13979 16  32.644  15.876 1.357973e-01 cattcaggttttatct   ASASASSASASASASA
# 13964 13980 16  32.350  21.612 1.607845e-01 attcaggttttatcta   SASASASAASASASAS
# 13965 13981 16  33.999  17.805 5.507069e-02 ttcaggttttatctat   ASASSASASASASASA
# 13966 13982 16  33.422  18.014 8.298358e-02 tcaggttttatctatt   SASASAASASASASAS
# 13967 13983 16  33.937  17.610 5.764046e-02 caggttttatctattt   ASSASASASASASASA
# 13968 13984 16  33.878  17.882 6.019633e-02 aggttttatctatttt   SASAASASASASASAS
# ...

# %%
import pandas as pd
data=pd.read_csv("eboVir3.fa.Z-SCORE", skiprows=1, names=["Start","End","1","2","3","Score","Seq","4"], delim_whitespace=True)
data.loc[data['Score'] >= 150]
# Out:
#        Start    End   1       2       3     Score                     Seq  \
# 6439    6440   6456  16  22.806  46.898  169.2888        gtgccggtatgtgcac
# 8634    8635   8657  22  22.908  46.198  152.3017  aggagcgcctcacaagtgcgcg
# 8636    8637   8657  20  22.742  46.585  181.0452    gagcgcctcacaagtgcgcg
# 8638    8639   8657  18  22.596  46.058  211.3387      gcgcctcacaagtgcgcg
# 8639    8640   8658  18  22.903  26.212  152.9743      cgcctcacaagtgcgcgt
# 8640    8641   8657  16  22.716  39.895  185.9997        gcctcacaagtgcgcg
# 8641    8642   8658  16  22.543  29.313  223.5817        cctcacaagtgcgcgt
# 8642    8643   8659  16  22.675  39.990  194.3437        ctcacaagtgcgcgtt
# 8643    8644   8660  16  22.430  29.941  252.6680        tcacaagtgcgcgttc
# 8644    8645   8661  16  22.725  39.097  184.3317        cacaagtgcgcgttcc
# 8645    8646   8662  16  22.423  29.834  254.6942        acaagtgcgcgttcct
# 8647    8648   8664  16  22.444  27.845  248.8339        aagtgcgcgttcctac
# ...

# %%
# !tail -n 1 eboVir3.fa.Z-SCORE
# Out:
# 18957 18973 16  25.549  30.229 1.523868e+01 ccggacacacaaaaag   SASASASASASASASA

# %%
# !head
# Out:
# ^C

# %%
pd.read_csv('eboVir3.fa.Z-SCORE')
# Out:
#                                    eboVir3.fa 18957 8 12
# 0      1 17 16  24.852  34.850 2.581158e+01 cggacacac...
# 1      2 18 16  26.251  23.856 9.480474e+00 ggacacaca...
# 2      3 19 16  27.048  19.898 5.914901e+00 gacacacaa...
# 3      4 20 16  27.544  16.375 4.566725e+00 acacacaaa...
# 4      5 21 16  27.544  16.392 4.566725e+00 cacacaaaa...
# ...                                                  ...
# 18952  18953 18969 16  23.367  47.948 9.611117e+01 gt...
# 18953  18954 18970 16  24.186  42.881 4.504430e+01 tg...
# 18954  18955 18971 16  24.399  40.586 3.747930e+01 gt...
# 18955  18956 18972 16  24.687  36.541 2.948049e+01 tc...
# 18956  18957 18973 16  25.549  30.229 1.523868e+01 cc...
#
# [18957 rows x 1 columns]
